# %% [markdown]
# <a href="https://colab.research.google.com/github/TyaraKusumaNevada/PCVK_Genap_2025/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)                           #perhatikan hasilnya adalah citra dgn channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)
#konversi channel BGR -> RGB

# %%
img_gray = cv.imread('/content/PCVK_MM/Images/kitten01.jpg', cv. IMREAD_GRAYSCALE)
plt.imshow(img_gray)
